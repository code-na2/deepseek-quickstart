# %%
def mock_query_product_data(product_name: str) -> str:
    if "深海蓝藻保湿面膜" in product_name:
        # 加载另一个文件中的实时变量
        # %run rag_rednote.ipynb
        return rag_rednote_text
    else:
        return f"产品数据库中未找到关于 '{product_name}' 的详细信息。"
